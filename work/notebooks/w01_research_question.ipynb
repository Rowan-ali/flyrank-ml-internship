# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Rowan-ali/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I chose the **Content Refresh Prioritization** lane because it focuses on helping content teams decide which pages should be reviewed and updated first. Since organizations often have limited time and resources, prioritizing the right pages can improve efficiency and help maintain search performance. I am interested in understanding which measurable factors are associated with declining pages and how data can support better content decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# This project aims to improve the decision of **which content pages should be reviewed and updated first**.
#
# The output will be used by **content editors and SEO specialists** to prioritize pages that are more likely to decline in search performance.
#
# A wrong recommendation could cause editors to spend time updating pages that do not need attention or overlook pages that are actually declining, leading to wasted effort and missed opportunities to improve search visibility.
#
# Machine learning is useful because this decision depends on several interacting signals that are difficult to combine accurately using a simple manual rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains **30,000 pages** and **44 features**.
#
# The correlation between **search volume** and **impressions** is **0.001**, indicating that search volume alone is not a strong indicator of page visibility.
#
# The median content age varies across trend directions, ranging from **216 days** for declining pages to **300 days** for stable pages, suggesting that content age may be associated with content performance.
#
# These observations indicate that multiple measurable factors should be considered when deciding which pages require attention.

# %%
import os
import sys
import subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

print("Working directory:", os.getcwd())

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.shape)
# Out:
# Working directory: /content/flyrank-ml-internship-starter
# (30000, 44)

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Dataset Shape:", df.shape)
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

corr = df["search_volume"].corr(df["impressions_90d"])
print("\nCorrelation between search volume and impressions:", round(corr, 3))

print("\nMedian content age by trend direction:")
print(df.groupby("trend_direction")["content_age_days"].median())
# Out:
# Dataset Shape: (30000, 44)
# Rows: 30000
# Columns: 44
#
# Correlation between search volume and impressions: 0.001
#
# Median content age by trend direction:
# trend_direction
# down      216.0
# flat      231.0
# new       279.0
# stable    300.0
# up        291.5
# Name: content_age_days, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project will provide **observed**, **measured**, **directional**, and **decision-support** insights based on the available dataset.
#
# The analysis may help content teams prioritize pages for review and identify patterns associated with declining performance. However, it will **not** prove causal relationships, determine Google's ranking algorithm, or guarantee future search performance. Any conclusions should be interpreted as evidence from the observed dataset rather than definitive proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
